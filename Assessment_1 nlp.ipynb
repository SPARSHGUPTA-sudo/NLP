# %% [markdown]
# sparsh gupta 2186
#
# TASK - 1

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

print("Shape:", df.shape)
print("Dimensions:", df.ndim)
print("Size:", df.size)

print("\nColumns:")
print(df.columns.tolist())

print("\nData Types:")
print(df.dtypes)

display(df.head())
# Out:
# Shape: (891, 12)
# Dimensions: 2
# Size: 10692
#
# Columns:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
#
# Data Types:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Line Graph
class_count = df["Pclass"].value_counts().sort_index()
plt.plot(class_count.index, class_count.values, marker="o")
plt.xlabel("Passenger Class")
plt.ylabel("Number of Passengers")
plt.title("Passengers by Class")
plt.show()

# %%
# Bar Graph
survival_gender = df.groupby("Sex")["Survived"].sum()
plt.bar(survival_gender.index, survival_gender.values)
plt.xlabel("Gender")
plt.ylabel("Number of Survivors")
plt.title("Survivors by Gender")
plt.show()

# %%
# Histogram
plt.hist(df["Age"].dropna(), bins=20)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Age Distribution")
plt.show()

# %%
# Pie Chart
df["Survived"].value_counts().plot.pie(
    labels=["Did Not Survive", "Survived"],
    autopct="%1.1f%%"
)
plt.title("Survival Distribution")
plt.ylabel("")
plt.show()

# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt

# Load Titanic dataset
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# Save DataFrame as PKL
df.to_pickle("titanic.pkl")

# Read PKL file
data = pd.read_pickle("titanic.pkl")

# Display data
print("First 5 rows:")
display(data.head())

# Display properties
print("Shape:", data.shape)
print("Dimensions:", data.ndim)
print("Size:", data.size)

print("\nData Types:")
print(data.dtypes)

# Visualization
class_count = data["Pclass"].value_counts().sort_index()

plt.bar(class_count.index, class_count.values)
plt.xlabel("Passenger Class")
plt.ylabel("Number of Passengers")
plt.title("Passengers by Class")
plt.show()
# Out:
# First 5 rows:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# Shape: (891, 12)
# Dimensions: 2
# Size: 10692
#
# Data Types:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy as np
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/pytorch/hub/master/images/dog.jpg"

response = requests.get(url)
image = Image.open(BytesIO(response.content))
image_array = np.array(image)

print("Format:", image.format)
print("Size:", image.size)
print("Dimensions:", image_array.ndim)
print("Shape:", image_array.shape)
print("Data Type:", image_array.dtype)

plt.figure(figsize=(6, 6))
plt.imshow(image)
plt.title("Image Plot")
plt.axis("off")
plt.show()

gray = np.mean(image_array, axis=2)

x = np.arange(gray.shape[1])
y = np.arange(gray.shape[0])
X, Y = np.meshgrid(x, y)

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection="3d")
ax.plot_surface(X, Y, gray, cmap="viridis")
ax.set_title("3D Plot of Image")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Intensity")
plt.show()
# Out:
# Format: JPEG
# Size: (1546, 1213)
# Dimensions: 3
# Shape: (1213, 1546, 3)
# Data Type: uint8

# %%
import requests
from IPython.display import Video, display

url = "https://github.com/rafaelreis-hotmart/Audio-Sample-files/raw/master/sample.mp4"

response = requests.get(url)
with open("sample.mp4", "wb") as f:
    f.write(response.content)

print("Video Format: MP4")
print("File Size:", len(response.content), "bytes")

display(Video("sample.mp4", embed=True))
# Out:
# Video Format: MP4
# File Size: 1570024 bytes
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
import requests
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from IPython.display import Audio, display

url = "https://raw.githubusercontent.com/pdx-cs-sound/wavs/main/sine.wav"

response = requests.get(url)
with open("sine.wav", "wb") as f:
    f.write(response.content)

sample_rate, audio = wavfile.read("sine.wav")

print("Format: WAV")
print("Sample Rate:", sample_rate)
print("Shape:", audio.shape)
print("Dimensions:", audio.ndim)
print("Size:", audio.size)

display(Audio("sine.wav"))

plt.figure(figsize=(10, 4))
plt.specgram(audio, Fs=sample_rate)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.title("Audio Spectrogram")
plt.colorbar(label="Intensity")
plt.show()
# Out:
# Format: WAV
# Sample Rate: 48000
# Shape: (48000,)
# Dimensions: 1
# Size: 48000
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
|import requests
import nltk

nltk.download("punkt")
nltk.download("punkt_tab")

from nltk.tokenize import sent_tokenize, word_tokenize

url = "https://raw.githubusercontent.com/selva86/datasets/master/sample.txt"

text = requests.get(url).text

sentences = sent_tokenize(text)
words = word_tokenize(text)

print("Number of Sentences:", len(sentences))
print("Number of Words:", len(words))

print("\nSentence Tokenization:")
for i, sentence in enumerate(sentences[:5], 1):
    print(i, sentence)

print("\nWord Tokenization:")
print(words[:50])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Number of Sentences: 5
# Number of Words: 180
#
# Sentence Tokenization:
# 1 The think tank of China’s People’s Liberation Army Rocket Force recently recruited 13 Chinese technicians
#  from private companies, PLA Daily reported on Saturday.
# 2 Zhang Hao and 12 other science and technology experts received letters of appointment at the founding ceremony of
# the PLA Rocket Force national defense science and technology experts panel, according to a report published by the
# PLA Daily on Saturday.
# 3 Honored as “rocket force science and technology experts,” Zhang and his fellow experts from private companies will
# serve as members of the PLA Rocket Force think tank, which will conduct research into fields like overall design of
# the missiles, missile launching and network system technology for five years.
# 4 The experts will enjoy the same treatment as their counterparts from State-owned firms, the report said.
# 5 The PLA Daily said that this marks a new development in deepening military-civilian integration in China, which
# could make science and technology innovation better contribute to the enhancement of the force’s combat capabilities.
#
# Word Tokenization:
# ['The', 'think', 'tank', 'of', 'China', '’', 's', 'People', '’', 's', 'Liberation', 'Army', 'Rocket', 'Force', 'recently', 'recruited', '13', 'Chinese', 'technicians', 'from', 'private', 'companies', ',', 'PLA', 'Daily', 'reported', 'on', 'Saturday', '.', 'Zhang', 'Hao', 'and', '12', 'other', 'science', 'and', 'technology', 'experts', 'received', 'letters', 'of', 'appointment', 'at', 'the', 'founding', 'ceremony', 'of', 'the', 'PLA', 'Rocket']

# %% [markdown]
# Task - 2

# %%
# !pip install contractions -q

import re
import contractions

paragraphs = [
""" OMG!! I can't believe I found this aWesoMe article about AI & machine leanring!! It was soooo gooood lol. I <3 nlp butttt i hate spelng errors in textttt. This is gonna be a looong paragraph with looooots of spacesss and weirddddd symbols @#$%. The website's link is www.example.com//// Check it out ASAP!!! #excited""",

""" Oh my gosh!!! Like, I can't even believe what I just stumbled upon on the world wide web. This article, "The Marvels of Artificial General Intelligence & the Future of Humanity," totally blew my mindddd!! It was, like, sooo mind-blowingly awesome, lolz. I mean, I <3 NLP butttt those annoying typos in texts drive me nuts. Brace yourselves, this is gonna be one seriously long paragraph with tons and tons of extraterrestrial spaces and some seriously weird symbols like @#$%. And guess what? The link to the website is www.incrediblenews.com//// So, um, you better check it out like ASAP!!! #excitedmuch""",

"""yaaayyyy!!! just watched thisssss AMAZZZING vid on AI & how it’s changin' evrythinggg!! it waz soooo dopeee, i can’t even... lolzzz! #blessed #mindblownn... btw, the link is http://coolai.stuff.com//// totally worthhh ittttt @@@!!! i <3 tech so much but sometimes it's likee realllyyy confusingggg!!!""",

"""nooo waayyyyy!!!! this is, like, the 1000000th time i've seen ppl mess up spellings in their blogsssss i mean c'mon, u're writing abt deep learning, not sum joke topic anywayzzzz... the article was kinda cooool butttt had lotsa weird $$$%%%@@ symbols all over. you can read it @ www.badblogger.ai//// and let me knw ur thots ASAP!!!""",

"""heyyyyy, did u read that crazyyyyyyy article on quantum stuff & ai?? like for realll... it wuz crazzzzy detailed but sooooo complicateddd!!! i cud barely undrstnd half of it . the diagrams were tho!!! i found it here – www.quantmgeekzz.net//// … plz plz plz read n tell me what u thinkk #toomuchinfo #brainhurts @@@!!!"""
]

def clean_text(text):

    text = text.lower()
    text = contractions.fix(text)

    text = text.replace("<3", "love")

    # Remove URLs
    text = re.sub(r'https?://\S+|www\.\S+', '', text)

    # Reduce duplicate letters
    text = re.sub(r'(.)\1{2,}', r'\1\1', text)

    # Remove special characters
    text = re.sub(r'[@#$%&*]', '', text)

    # remove punctuation
    text = re.sub(r'[!?.]+', ' ', text)

    # Remove remaining special characters
    text = re.sub(r'[^\w\s.!?]', ' ', text)

    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()

    return text


cleaned_paragraphs = []

for paragraph in paragraphs:
    cleaned = clean_text(paragraph)
    cleaned_paragraphs.append(cleaned)


for i, paragraph in enumerate(cleaned_paragraphs, 1):
    print("CLEANED PARAGRAPH", i)
    print(paragraph)
    print()
# Out:
# CLEANED PARAGRAPH 1
# omg i cannot believe i found this awesome article about ai machine leanring it was soo good lol i love nlp butt i hate spelng errors in textt this is going to be a loong paragraph with loots of spacess and weirdd symbols the website s link is check it out as soon as possible excited
#
# CLEANED PARAGRAPH 2
# oh my gosh like i cannot even believe what i just stumbled upon on the world wide web this article the marvels of artificial general intelligence the future of humanity totally blew my mindd it was like soo mind blowingly awesome lolz i mean i love nlp butt those annoying typos in texts drive me nuts brace yourselves this is going to be one seriously long paragraph with tons and tons of extraterrestrial spaces and some seriously weird symbols like and guess what the link to the website is so um you better check it out like as soon as possible excitedmuch
#
# CLEANED PARAGRAPH 3
# yaayy just watched thiss amazzing vid on ai how it is changin evrythingg it waz soo dopee i cannot even lolzz blessed mindblownn by the way the link is totally worthh itt i love tech so much but sometimes it is likee reallyy confusingg
#
# CLEANED PARAGRAPH 4
# noo waayy this is like the 100th time i have seen people mess up spellings in their blogss i mean c mon you re writing about deep learning not sum joke topic anywayzz the article was kind of cool butt had lotsa weird symbols all over you can read it and let me knw you are thots as soon as possible
#
# CLEANED PARAGRAPH 5
# heyy did you read that crazyy article on quantum stuff ai like for reall it wuz crazzy detailed but soo complicatedd i cud barely undrstnd half of it the diagrams were though i found it here plz plz plz read n tell me what you thinkk toomuchinfo brainhurts
